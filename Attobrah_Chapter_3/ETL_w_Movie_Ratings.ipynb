# %%
# !pip3 install pyjanitor==0.28.1
# !pip3 install pandas==2.2.2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import janitor

# %%
rating_data = pd.read_csv("ratings.csv", skipinitialspace=True, header=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rating_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                             0       1  \
# 0         2022-09-19T19:46:59  147179
# 1         2022-09-19T19:46:59  235248
# 2         2022-09-19T19:47:01    9465
# 3         2022-09-19T19:47:01  205897
# 4         2022-09-19T19:47:04   41609
# ...                       ...     ...
# 14051777  2022-11-05T01:43:02  598948
# 14051778  2022-11-05T01:43:03  240511
# 14051779  2022-11-05T01:43:03  439162
# 14051780  2022-11-05T01:43:03  602405
# 14051781  2022-11-05T01:43:03   89187
#
#                                                          2  3
# 0                                        voodoo+tiger+1952  4
# ...

# %%
rating_data = (rating_data
               .rename_column(0,'date/time')
               .rename_column(1,'user_id')
               .rename_column(2,'movie_id')
               .rename_column(3,'rating'))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rating_data.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                   date/time   user_id                       movie_id    rating
# count              14051782  14051782                       14051782  14051782
# unique              3733123   1428312                          27261        28
# top     2022-11-01T22:18:41    344352  the+shawshank+redemption+1994         4
# freq                     22        65                         176748   6476617

# %%
rating_data["rating"].unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([4, 2, 5, 3, 1, '5', '4', '3', '2', '1', 'D', 'E', 'F', 'N4', 'B',
#        'v3', 'C', 't3', 'Q4', 'J3', '44', 'W4', '14', '54', '63', 'z5',
#        '55', 'd5'], dtype=object)

# %%
rating_data["rating"].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# rating
# 4     6476617
# 5     2902433
# 3     2573853
# 4      988404
# 5      443426
# 3      393134
# 2      228598
# 2       35199
# 1        8195
# 1        1312
# E         332
# F         144
# D         110
# C          11
# 55          1
# W4          1
# z5          1
# 63          1
# 54          1
# 14          1
# B           1
# 44          1
# J3          1
# Q4          1
# t3          1
# v3          1
# N4          1
# d5          1
# Name: count, dtype: int64

# %%
rating_data["date/time"].apply(type).value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# date/time
# <class 'str'>    14051782
# Name: count, dtype: int64

# %%
rating_data["user_id"].apply(type).value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# user_id
# <class 'int'>    12189696
# <class 'str'>     1862086
# Name: count, dtype: int64

# %%
rating_data["movie_id"].apply(type).value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# movie_id
# <class 'str'>    14051782
# Name: count, dtype: int64

# %%
rating_data["rating"].apply(type).value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# rating
# <class 'int'>    12189696
# <class 'str'>     1862086
# Name: count, dtype: int64

# %%
rating_data = (rating_data
               .change_type("rating", dtype=int, ignore_exception="fillna")
               .change_type("user_id", dtype=int, ignore_exception="fillna")
               .to_datetime("date/time", format="ISO8601", errors="coerce")
               .dropna()
               .reset_index(drop=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rating_data.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             date/time   user_id  \
# 0 2022-09-19 19:46:59  147179.0
# 1 2022-09-19 19:46:59  235248.0
# 2 2022-09-19 19:47:01    9465.0
# 3 2022-09-19 19:47:01  205897.0
# 4 2022-09-19 19:47:04   41609.0
#
#                                            movie_id  rating
# 0                                 voodoo+tiger+1952     4.0
# 1  sazen+tange+and+the+pot+worth+a+million+ryo+1935     4.0
# 2                               body+snatchers+1993     2.0
# 3                                 total+recall+1990     5.0
# 4                           portrait+of+jennie+1948     3.0

# %%
rating_data = (rating_data
               .change_type("rating", dtype=int, ignore_exception="fillna")
               .change_type("user_id", dtype=int, ignore_exception="fillna")
               .dropna()
               .reset_index(drop=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rating_data.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             date/time  user_id  \
# 0 2022-09-19 19:46:59   147179
# 1 2022-09-19 19:46:59   235248
# 2 2022-09-19 19:47:01     9465
# 3 2022-09-19 19:47:01   205897
# 4 2022-09-19 19:47:04    41609
#
#                                            movie_id  rating
# 0                                 voodoo+tiger+1952       4
# 1  sazen+tange+and+the+pot+worth+a+million+ryo+1935       4
# 2                               body+snatchers+1993       2
# 3                                 total+recall+1990       5
# 4                           portrait+of+jennie+1948       3

# %%
rating_data.to_csv("clean_rating_data.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
