# %%
# !pip3 install faker

# %%
from faker import Faker
import pandas as pd
import random

# %%
fake_data = Faker("en_US")

# %%
people = []
phonenumbers = []
incomes = []


for i in range(10):
  person_name = fake_data.name()
  phone_nomber = fake_data.phone_number()
  income = random.randrange(40000,200000)
  people.append(person_name)
  phonenumbers.append(phone_nomber)
  incomes.append(income)

# %%
sample_data = pd.DataFrame()

sample_data["People"] = people
sample_data["Phone Number"] = phonenumbers
sample_data["Income"] = incomes

# %%
sample_data
# Out:
#               People           Phone Number  Income
# 0      Anthony Avila    +1-227-874-2486x878  185205
# 1      Kimberly Cruz           960.649.0885  149386
# 2      Cassidy Adams  001-285-410-5956x4515  168926
# 3      Justin Holmes      (695)708-9488x072   54419
# 4      Jasmine Lopez           554-924-9009  105524
# 5      Amber Sanchez    (851)225-3475x80479  184795
# 6  Gregory Rodriguez      825.709.8450x5884   62139
# 7       James Greene           595-814-0918  163618
# 8          John Reed       001-938-957-3118  177171
# 9     Colleen Martin             8658095302  181263

# %%
sample_data.to_csv("synthetic_data.csv", index=False)
