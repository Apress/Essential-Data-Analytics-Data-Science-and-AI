# %%
# !pip3 install yfinance

# %%
import yfinance as yf

# %%
apple_data = yf.download("AAPL",
              start = "2020-01-01",
              end = "2022-12-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.249008  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.536911  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.114891  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.771042  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.941643  132079200

# %%
apple_data["Adj Close"].plot(title = "Apple Stock Price 2020-2022")
# Out:
# <Axes: title={'center': 'Apple Stock Price 2020-2022'}, xlabel='Date'>
