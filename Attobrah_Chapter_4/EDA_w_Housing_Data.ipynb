# %%
# !pip3 install matplotlib
# !pip3 install pandas
# !pip3 install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_csv("USA Housing Dataset.csv")

# %%
# Basic exploration
housing_data.sample(5)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 400   2014-05-19 00:00:00   475000.0       2.0       1.00         1490
# 2900  2014-06-25 00:00:00   450000.0       4.0       2.75         2310
# 1623  2014-06-08 00:00:00  2700000.0       4.0       3.25         4420
# 1006  2014-05-28 00:00:00   820000.0       3.0       2.50         2510
# 3195  2014-06-30 00:00:00   550000.0       3.0       2.25         1720
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 400       3825     1.0           0     0          3         860
# 2900      5650     1.0           0     2          3        1330
# 1623      7850     2.0           1     4          3        3150
# 1006      5503     2.0           0     2          3        2510
# 3195      9600     1.0           0     0          4        1220
#
#       sqft_basement  yr_built  yr_renovated                 street      city  \
# ...

# %%
housing_data[housing_data["price"]>1500000][["city"]].value_counts()
# Out:
# city
# Seattle          37
# Bellevue         21
# Mercer Island    17
# Medina            8
# Kirkland          6
# Fall City         2
# Issaquah          2
# Clyde Hill        2
# Shoreline         2
# Yarrow Point      2
# Kent              1
# Carnation         1
# Covington         1
# Redmond           1
# Sammamish         1
# Tukwila           1
# Woodinville       1
# Name: count, dtype: int64

# %%
# Correlation matrix
correlation_matrix = housing_data[["price","bedrooms","bathrooms","yr_built","floors","waterfront","sqft_living"]].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
sorted_data = data.sort_values(by=["date"])

# %%
plt.figure(figsize=(20,20))

# %%
# Out:
# city
# Seattle          37
# Bellevue         21
# Mercer Island    17
# Medina            8
# Kirkland          6
# Fall City         2
# Issaquah          2
# Clyde Hill        2
# Shoreline         2
# Yarrow Point      2
# Kent              1
# Carnation         1
# Covington         1
# Redmond           1
# Sammamish         1
# Tukwila           1
# Woodinville       1
# Name: count, dtype: int64
